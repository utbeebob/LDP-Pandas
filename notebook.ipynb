# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions:
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
netflix_df=pd.read_csv("netflix_data.csv")
print(netflix_df.iloc[0:10])
netflix_subset = netflix_df[netflix_df["type"] =="Movie"]
netflix_movies = netflix_subset[['title', 'country', 'genre', 'release_year', 'duration']]
short_movies = netflix_movies[netflix_movies['duration']<60]
print(short_movies.iloc[0:10])
colors = []

for lab, row in netflix_movies.iterrows():
   
    if row['genre'] == "Children":
        colors.append('pink')
    elif row['genre'] == "Documentaries":
        colors.append('blue')
    elif row['genre'] == "Stand-Up":
        colors.append('black')
    else:
        colors.append('yellow')
    
print(colors)

fig = plt.figure(figsize=(8,12))
x = netflix_movies['duration']
y = netflix_movies['release_year']
plt.scatter(y,x, c=colors)
plt.ylabel("Duration (min)")
plt.xlabel('Release year')
plt.title("Movie Duration by Year of Release")

answer = 'maybe'
# Out:
#   show_id  ...             genre
# 0      s1  ...  International TV
# 1      s2  ...            Dramas
# 2      s3  ...     Horror Movies
# 3      s4  ...            Action
# 4      s5  ...            Dramas
# 5      s6  ...  International TV
# 6      s7  ...     Horror Movies
# 7      s8  ...            Dramas
# 8      s9  ...     Horror Movies
# 9     s10  ...     Horror Movies
#
# [10 rows x 11 columns]
#                                                  title  ... duration
# 35                                           #Rucker50  ...       56
# 55                 100 Things to do Before High School  ...       44
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...  ...       37
# 101                                  3 Seconds Divorce  ...       53
# 146                                     A 3 Minute Hug  ...       28
# 162  A Christmas Special: Miraculous: Tales of Lady...  ...       22
# 171                         A Family Reunion Christmas  ...       29
# 177                    A Go! Go! Cory Carson Christmas  ...       22
# 178                    A Go! Go! Cory Carson Halloween  ...       22
# 179                  A Go! Go! Cory Carson Summer Camp  ...       21
#
# [10 rows x 5 columns]
# ['yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'blue', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'pink', 'pink', 'pink', 'yellow', 'pink', 'pink', 'yellow', 'yellow', 'pink', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'pink', 'pink', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'blue', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'pink', 'yellow', 'black', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'pink', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'pink', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'black', 'black', 'yellow', 'yellow', 'black', 'yellow', 'black', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'black', 'yellow', 'blue', 'blue', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'black', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'black', 'yellow', 'yellow', 'yellow', 'pink', 'black', 'blue', 'yellow', 'black', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'yellow', 'black', 'black', 'yellow', 'blue', 'yellow', 'yellow', 'yellow', 'blue', 'yellow', 'pink', 'pink', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'pink', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'pink', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'blue', 'blue', 'blue', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'black', 'yellow', 'yellow', 'blue', 'black', 'black', 'blue', 'pink', 'pink', 'pink', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'black', ' ...
